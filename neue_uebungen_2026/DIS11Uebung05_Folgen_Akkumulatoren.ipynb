# %% [markdown]
# # 5. Übung: Folgen, Summen und Akkumulatoren
#
# Diese Übung verbindet Quantoren, Summen- und Produktnotation, arithmetische und geometrische Folgen mit typischen Schleifenmustern: Akkumulator, Zähler sowie Minimum und Maximum.
#
# Verwenden Sie für die Rechenaufgaben bewusst eigene Schleifen und nicht `sum`, `min` oder `max`.

# %% [markdown]
# ### So arbeiten Sie mit den Doctests
#
# Die Beispiele in den Funktions-Dokumentationen sind ausführbare Tests. Ergänzen Sie nur den markierten Funktionskörper und lassen Sie die Beispiele zunächst unverändert. Führen Sie am Ende des Notebooks die Zelle **Doctests ausführen** aus. `0 failed` bedeutet, dass alle bisher vorgegebenen Fälle funktionieren. Testen Sie zusätzlich eigene Fälle.

# %%
import doctest

# %% [markdown]
# ## 1. Arithmetische und geometrische Folgen
#
# Schreiben Sie Funktionen, die die ersten `anzahl` Glieder als Liste zurückgeben. Bei `anzahl=0` ist die Liste leer.
#
# * Arithmetisch: nächstes Glied = vorheriges Glied + `differenz`.
# * Geometrisch: nächstes Glied = vorheriges Glied * `faktor`.

# %%
def arithmetische_folge(start, differenz, anzahl):
    """Erzeugt die ersten Glieder einer arithmetischen Folge.

    >>> arithmetische_folge(2, 3, 5)
    [2, 5, 8, 11, 14]
    >>> arithmetische_folge(10, -2, 4)
    [10, 8, 6, 4]
    >>> arithmetische_folge(1, 1, 0)
    []
    """
    pass


def geometrische_folge(start, faktor, anzahl):
    """Erzeugt die ersten Glieder einer geometrischen Folge.

    >>> geometrische_folge(2, 3, 4)
    [2, 6, 18, 54]
    >>> geometrische_folge(5, 0, 3)
    [5, 0, 0]
    """
    pass

# %% [markdown]
# ## 2. Summe und Produkt als Akkumulator
#
# Schreiben Sie `summe_der_folge` und `produkt_der_folge`. Die Summe bzw. das Produkt soll in einer Schleife aufgebaut werden. Für das leere Produkt verwenden wir den neutralen Wert `1`.

# %%
def summe_der_folge(werte):
    """Addiert alle Werte mit einem Akkumulator.

    >>> summe_der_folge([2, 5, 8, 11, 14])
    40
    >>> summe_der_folge([])
    0
    """
    pass


def produkt_der_folge(werte):
    """Multipliziert alle Werte mit einem Akkumulator.

    >>> produkt_der_folge([2, 3, 4])
    24
    >>> produkt_der_folge([])
    1
    """
    pass

# %% [markdown]
# ## 3. Quantoren und Zähler
#
# Schreiben Sie `alle_im_intervall(werte, unten, oben)`. Die Funktion entspricht dem Quantor „für alle“ und liefert `False`, sobald ein Wert außerhalb des geschlossenen Intervalls liegt. Zählen Sie zusätzlich mit `anzahl_gerader(werte)`, wie viele Werte gerade sind.

# %%
def alle_im_intervall(werte, unten, oben):
    """Prüft, ob alle Werte im geschlossenen Intervall liegen.

    >>> alle_im_intervall([2, 4, 6], 1, 6)
    True
    >>> alle_im_intervall([2, 7, 6], 1, 6)
    False
    >>> alle_im_intervall([], 1, 6)
    True
    """
    pass


def anzahl_gerader(werte):
    """Zählt die geraden Werte einer Folge.

    >>> anzahl_gerader([1, 2, 4, 7, 8])
    3
    >>> anzahl_gerader([])
    0
    """
    pass

# %% [markdown]
# ## 4. Minimum und Maximum ohne eingebaute Funktionen
#
# Schreiben Sie `min_max(werte)`. Geben Sie ein Tupel `(kleinstes, größtes)` zurück. Die Eingabe enthält mindestens einen Wert. Starten Sie beide Akkumulatoren mit dem ersten Element und arbeiten Sie dann den Rest der Folge ab.

# %%
def min_max(werte):
    """Liefert Minimum und Maximum einer nichtleeren Folge.

    >>> min_max([4, 1, 9, 2])
    (1, 9)
    >>> min_max([-3, -8, -1])
    (-8, -1)
    >>> min_max([5])
    (5, 5)
    """
    pass

# %% [markdown]
# ### Zusatz
#
# Kombinieren Sie die Funktionen: Erzeugen Sie die ersten 10 Glieder einer Folge, berechnen Sie deren Summe und bestimmen Sie Minimum und Maximum.

# %% [markdown]
# ## Weitere Aufgabensammlung
#
# Die folgenden Aufgaben sind als Auswahl gedacht. Bearbeiten Sie zunächst die Basisaufgaben und wählen Sie danach Zusatzaufgaben mit Beispielen aus dem Alltag oder der Datenanalyse.

# %% [markdown]
# ## 5. Fibonacci-Folge
#
# Schreiben Sie `fibonacci(anzahl)`. Geben Sie die ersten Glieder `0, 1, 1, 2, ...` als Liste zurück. Verwenden Sie zwei laufende Werte statt Rekursion.

# %%
def fibonacci(anzahl):
    """Erzeugt die ersten Glieder der Fibonacci-Folge.

    >>> fibonacci(0)
    []
    >>> fibonacci(1)
    [0]
    >>> fibonacci(7)
    [0, 1, 1, 2, 3, 5, 8]
    """
    pass

# %% [markdown]
# ## 6. Dreieckszahlen
#
# Schreiben Sie `dreieckszahlen(anzahl)`. Die Folge beginnt mit `1, 3, 6, 10, ...`; jedes neue Glied entsteht durch Aufaddieren des nächsten Zählers.

# %%
def dreieckszahlen(anzahl):
    """Erzeugt die ersten Dreieckszahlen.

    >>> dreieckszahlen(0)
    []
    >>> dreieckszahlen(5)
    [1, 3, 6, 10, 15]
    """
    pass

# %% [markdown]
# ## 7. Quadratsumme
#
# Schreiben Sie `quadratsumme(n)` und berechnen Sie `1² + 2² + ... + n²` mit einem Akkumulator. Für `n=0` ist die Summe 0.

# %%
def quadratsumme(n):
    """Berechnet die Summe der Quadrate von 1 bis n.

    >>> quadratsumme(0)
    0
    >>> quadratsumme(4)
    30
    >>> quadratsumme(10)
    385
    """
    pass

# %% [markdown]
# ## 8. Geometrische Summe
#
# Schreiben Sie `geometrische_summe(start, faktor, anzahl)`. Addieren Sie `start`, `start*faktor`, ... für genau `anzahl` Glieder.

# %%
def geometrische_summe(start, faktor, anzahl):
    """Summiert die ersten Glieder einer geometrischen Folge.

    >>> geometrische_summe(1, 2, 4)
    15
    >>> geometrische_summe(3, 3, 3)
    39
    >>> geometrische_summe(5, 10, 0)
    0
    """
    pass

# %% [markdown]
# ## 9. Werte über einer Grenze zählen
#
# Schreiben Sie `zaehle_groesser(werte, grenze)`. Zählen Sie, wie viele Werte strikt größer als die Grenze sind.

# %%
def zaehle_groesser(werte, grenze):
    """Zählt Werte, die strikt größer als grenze sind.

    >>> zaehle_groesser([1, 7, 4, 9], 5)
    2
    >>> zaehle_groesser([5, 5], 5)
    0
    >>> zaehle_groesser([], 5)
    0
    """
    pass

# %% [markdown]
# ## 10. Erste Grenzüberschreitung
#
# Schreiben Sie `erste_position_ueber(werte, grenze)`. Geben Sie den ersten Index mit einem Wert größer als die Grenze zurück; wenn keiner existiert, geben Sie `-1` zurück.

# %%
def erste_position_ueber(werte, grenze):
    """Findet den ersten Index eines Werts über der Grenze.

    >>> erste_position_ueber([2, 4, 7, 1], 5)
    2
    >>> erste_position_ueber([1, 2, 3], 5)
    -1
    >>> erste_position_ueber([], 0)
    -1
    """
    pass

# %% [markdown]
# ## 11. Laufendes Maximum
#
# Schreiben Sie `laufendes_maximum(werte)`. Für einen Datenstrom soll nach jeder neuen Beobachtung das bisherige Maximum gespeichert werden.

# %%
def laufendes_maximum(werte):
    """Erzeugt die Folge der bisher beobachteten Maxima.

    >>> laufendes_maximum([3, 1, 4, 2, 5])
    [3, 3, 4, 4, 5]
    >>> laufendes_maximum([])
    []
    """
    pass

# %% [markdown]
# ## 12. Gleitender Mittelwert
#
# Schreiben Sie `gleitender_mittelwert(werte, fenster)`. Berechnen Sie für jedes vollständige Fenster den Mittelwert. Bei `[1,2,3,4]` und Fenster 2 entstehen drei Werte.

# %%
def gleitender_mittelwert(werte, fenster):
    """Berechnet einfache gleitende Mittelwerte.

    >>> gleitender_mittelwert([1, 2, 3, 4], 2)
    [1.5, 2.5, 3.5]
    >>> gleitender_mittelwert([1, 2, 3, 4], 3)
    [2.0, 3.0]
    >>> gleitender_mittelwert([1, 2], 3)
    []
    """
    pass

# %% [markdown]
# ## 13. Häufigkeiten einfacher Kategorien
#
# Schreiben Sie `haeufigkeiten(werte, kategorien)`. Zählen Sie für jede Kategorie, wie oft sie in `werte` vorkommt. Verwenden Sie zunächst kein Dictionary.

# %%
def haeufigkeiten(werte, kategorien):
    """Zählt die Häufigkeit jeder vorgegebenen Kategorie.

    >>> haeufigkeiten(['rot', 'blau', 'rot'], ['rot', 'blau', 'gruen'])
    [2, 1, 0]
    >>> haeufigkeiten([], ['ja', 'nein'])
    [0, 0]
    """
    pass

# %% [markdown]
# ## 14. Skalarprodukt für Merkmale
#
# Schreiben Sie `skalarprodukt(a, b)`. Multiplizieren Sie gleich positionierte Werte und addieren Sie die Produkte. Dieses Muster steht hinter einer einfachen linearen Bewertung von Datenmerkmalen.

# %%
def skalarprodukt(a, b):
    """Berechnet das Skalarprodukt zweier gleich langer Folgen.

    >>> skalarprodukt([1, 2, 3], [10, 20, 30])
    140
    >>> skalarprodukt([0.5, 2], [4, 3])
    8.0
    >>> skalarprodukt([], [])
    0
    """
    pass

# %% [markdown]
# ## Doctests ausführen

# %%
ergebnis = doctest.testmod(globs=globals(), verbose=True)
print(ergebnis)
