# %% [markdown]
# # 1. Übung: Zahlensysteme und formatierte Ausgabe
#
# Diese Übung passt zur Einführung in Dual-, Oktal- und Hexadezimalsysteme. Sie üben Stellenwerte, ganzzahlige Division, Restbildung und gut lesbare Ausgaben.
#
# **Voraussetzungen:** Verwenden Sie für die Umrechnungen nicht `bin()`, `oct()`, `hex()` oder `int(text, basis)`. Die Eingaben in den Beispielen sind gültig: Es gelten die Basen 2, 8 und 16 sowie nichtnegative Zahlen.

# %% [markdown]
# ### So arbeiten Sie mit den Doctests
#
# Die Beispiele in den Funktions-Dokumentationen sind ausführbare Tests. Ergänzen Sie nur den markierten Funktionskörper und lassen Sie die Beispiele zunächst unverändert. Führen Sie am Ende des Notebooks die Zelle **Doctests ausführen** aus. `0 failed` bedeutet, dass alle bisher vorgegebenen Fälle funktionieren. Testen Sie zusätzlich eigene Fälle.

# %%
import doctest

# %% [markdown]
# ## 1. Ziffern in einem Zahlensystem
#
# Schreiben Sie `ziffernwert(zeichen)`. Die Funktion liefert den Wert einer einzelnen Ziffer. Für das Hexadezimalsystem stehen `A` bis `F` für 10 bis 15. Groß- und Kleinschreibung sollen akzeptiert werden.

# %%
def ziffernwert(zeichen):
    """Liefert den Zahlenwert einer Ziffer.

    >>> ziffernwert("0")
    0
    >>> ziffernwert("9")
    9
    >>> ziffernwert("a")
    10
    >>> ziffernwert("F")
    15
    """
    pass

# %% [markdown]
# ## 2. Von einer Basis nach Dezimal
#
# Schreiben Sie `basis_zu_dezimal(zahl, basis)`. Lesen Sie die Zeichen von links nach rechts und berechnen Sie den Stellenwert selbst. Ein Beispiel: `"1011"` zur Basis 2 ist `1*2**3 + 0*2**2 + 1*2 + 1 = 11`.

# %%
def basis_zu_dezimal(zahl, basis):
    """Wandelt eine Zahl als Text in eine Dezimalzahl um.

    Erlaubte Basen sind 2, 8 und 16.

    >>> basis_zu_dezimal("1011", 2)
    11
    >>> basis_zu_dezimal("755", 8)
    493
    >>> basis_zu_dezimal("2A", 16)
    42
    >>> basis_zu_dezimal("0", 2)
    0
    """
    pass

# %% [markdown]
# ## 3. Von Dezimal in eine andere Basis
#
# Schreiben Sie `dezimal_zu_basis(zahl, basis)`. Verwenden Sie wiederholt `//` und `%`: Der Rest ist die jeweils nächste Ziffer von rechts. Die Funktion soll einen Text zurückgeben.

# %%
def dezimal_zu_basis(zahl, basis):
    """Wandelt eine nichtnegative Dezimalzahl in Basis 2, 8 oder 16 um.

    >>> dezimal_zu_basis(45, 2)
    '101101'
    >>> dezimal_zu_basis(493, 8)
    '755'
    >>> dezimal_zu_basis(42, 16)
    '2A'
    >>> dezimal_zu_basis(0, 2)
    '0'
    """
    pass

# %% [markdown]
# ## 4. Eine lesbare Ausgabezeile
#
# Schreiben Sie `formatierte_zeile(zahl)`. Die Funktion soll eine Zeichenkette mit allen vier Darstellungen zurückgeben. Verwenden Sie dafür Ihre eigene Umrechnungsfunktion.
#
# Beispiel für das gewünschte Format:
#
# ```text
# 42 | binaer=101010 | oktal=52 | hex=2A
# ```

# %%
def formatierte_zeile(zahl):
    """Erzeugt eine kompakte Darstellung in vier Zahlensystemen.

    >>> formatierte_zeile(42)
    '42 | binaer=101010 | oktal=52 | hex=2A'
    >>> formatierte_zeile(0)
    '0 | binaer=0 | oktal=0 | hex=0'
    """
    pass

# %% [markdown]
# ### Zusatz
#
# Erstellen Sie eine Tabelle für die Dezimalzahlen 0 bis 31. Nutzen Sie eine Schleife und Ihre Funktion `formatierte_zeile`.

# %% [markdown]
# ## Weitere Aufgabensammlung
#
# Die folgenden Aufgaben sind als Auswahl gedacht. Bearbeiten Sie zunächst die Basisaufgaben und wählen Sie danach Zusatzaufgaben mit Beispielen aus dem Alltag oder der Datenanalyse.

# %% [markdown]
# ## 5. Bit-Flags: Ist ein Bit gesetzt?
#
# Schreiben Sie `bit_gesetzt(zahl, stelle)`. Die Stelle 0 ist das niederwertigste Bit. Verwenden Sie nicht den Operator `&`, sondern üben Sie Division und Restbildung.

# %%
def bit_gesetzt(zahl, stelle):
    """Prüft, ob das Bit an der angegebenen Stelle 1 ist.

    >>> bit_gesetzt(5, 0)
    True
    >>> bit_gesetzt(5, 1)
    False
    >>> bit_gesetzt(5, 2)
    True
    """
    pass

# %% [markdown]
# ## 6. Anzahl gesetzter Bits
#
# Schreiben Sie `anzahl_einsen(zahl)`. Zählen Sie, wie viele Einsen die Binärdarstellung enthält. Das ist eine einfache Form einer Merkmalsextraktion aus einer Bitmaske.

# %%
def anzahl_einsen(zahl):
    """Zählt die Einsen in der Binärdarstellung einer nichtnegativen Zahl.

    >>> anzahl_einsen(0)
    0
    >>> anzahl_einsen(13)
    3
    >>> anzahl_einsen(255)
    8
    """
    pass

# %% [markdown]
# ## 7. Ein Byte darstellen
#
# Schreiben Sie `byte_zu_binaer(byte)`. Geben Sie genau acht Zeichen zurück und füllen Sie links mit Nullen auf. Die Eingabe liegt zwischen 0 und 255.

# %%
def byte_zu_binaer(byte):
    """Gibt ein Byte als achtstellige Binärzahl aus.

    >>> byte_zu_binaer(0)
    '00000000'
    >>> byte_zu_binaer(5)
    '00000101'
    >>> byte_zu_binaer(255)
    '11111111'
    """
    pass

# %% [markdown]
# ## 8. RGB-Farbe als Hexcode
#
# Schreiben Sie `rgb_zu_hex(rot, gruen, blau)`. Jede Farbkomponente liegt zwischen 0 und 255. Nutzen Sie Ihre Umrechnung und geben Sie einen sechsstelligen, großgeschriebenen Hexcode mit führendem `#` zurück.

# %%
def rgb_zu_hex(rot, gruen, blau):
    """Wandelt drei RGB-Komponenten in einen Hex-Farbcode um.

    >>> rgb_zu_hex(30, 144, 255)
    '#1E90FF'
    >>> rgb_zu_hex(0, 0, 0)
    '#000000'
    >>> rgb_zu_hex(255, 136, 0)
    '#FF8800'
    """
    pass

# %% [markdown]
# ## 9. Hexcode zurück in RGB
#
# Schreiben Sie die Umkehrung `hex_zu_rgb(farbe)`. Akzeptieren Sie sowohl `#1E90FF` als auch `1E90FF` und geben Sie ein Tupel `(rot, gruen, blau)` zurück.

# %%
def hex_zu_rgb(farbe):
    """Wandelt einen sechsstelligen Hex-Farbcode in ein RGB-Tupel um.

    >>> hex_zu_rgb('#1E90FF')
    (30, 144, 255)
    >>> hex_zu_rgb('000000')
    (0, 0, 0)
    >>> hex_zu_rgb('#FF8800')
    (255, 136, 0)
    """
    pass

# %% [markdown]
# ## 10. Hex-Farbe validieren
#
# Schreiben Sie `gueltige_hexfarbe(farbe)`. Erlaubt sind sechs Hexziffern, optional mit `#`. Die Funktion soll bei falscher Länge oder ungültigen Zeichen `False` liefern.

# %%
def gueltige_hexfarbe(farbe):
    """Prüft einen sechsstelligen RGB-Hexcode.

    >>> gueltige_hexfarbe('#1E90FF')
    True
    >>> gueltige_hexfarbe('00ff00')
    True
    >>> gueltige_hexfarbe('#FFF')
    False
    >>> gueltige_hexfarbe('#GG0000')
    False
    """
    pass

# %% [markdown]
# ## 11. Datenmengen in Bytes
#
# Schreiben Sie `datenmenge_in_bytes(wert, einheit)`. Unterstützen Sie die Einheiten `B`, `KiB` und `MiB`. Das Ergebnis soll eine ganze Zahl sein. Dies ist nützlich, wenn Messdateien oder Bilddaten eingelesen werden.

# %%
def datenmenge_in_bytes(wert, einheit):
    """Wandelt B, KiB oder MiB in Bytes um.

    >>> datenmenge_in_bytes(512, 'B')
    512
    >>> datenmenge_in_bytes(2, 'KiB')
    2048
    >>> datenmenge_in_bytes(1, 'MiB')
    1048576
    """
    pass

# %% [markdown]
# ## 12. Dateigröße lesbar ausgeben
#
# Schreiben Sie `dateigroesse_text(bytes)`. Verwenden Sie für mindestens B, KiB und MiB eine passende Einheit und genau zwei Nachkommastellen bei KiB/MiB.

# %%
def dateigroesse_text(bytes):
    """Formatiert eine Dateigröße für eine Statusmeldung.

    >>> dateigroesse_text(512)
    '512 B'
    >>> dateigroesse_text(1536)
    '1.50 KiB'
    >>> dateigroesse_text(1048576)
    '1.00 MiB'
    """
    pass

# %% [markdown]
# ## 13. Messwert mit Einheit
#
# Schreiben Sie `messwert_text(name, wert, einheit)`. Eine Messwertzeile soll immer zwei Nachkommastellen besitzen. So kann sie direkt in einem Protokoll verwendet werden.

# %%
def messwert_text(name, wert, einheit):
    """Formatiert einen benannten Messwert.

    >>> messwert_text('Temperatur', 23.456, '°C')
    'Temperatur: 23.46 °C'
    >>> messwert_text('pH', 7, '')
    'pH: 7.00 '
    """
    pass

# %% [markdown]
# ## 14. CSV-Zeile aus Messwerten
#
# Schreiben Sie `csv_zeile(werte)`. Formatieren Sie jede Zahl mit zwei Nachkommastellen und trennen Sie die Felder mit Semikolon und Leerzeichen. Das Ergebnis soll als einfache Tabellenzeile weiterverwendbar sein.

# %%
def csv_zeile(werte):
    """Formatiert eine Liste von Zahlen als einfache CSV-Zeile.

    >>> csv_zeile([1, 2.5, -0.25])
    '1.00; 2.50; -0.25'
    >>> csv_zeile([])
    ''
    """
    pass

# %% [markdown]
# ## Doctests ausführen

# %%
ergebnis = doctest.testmod(globs=globals(), verbose=True)
print(ergebnis)
