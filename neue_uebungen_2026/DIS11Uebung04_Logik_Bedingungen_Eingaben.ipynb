# %% [markdown]
# # 4. Übung: Aussagenlogik, Bedingungen und Eingaben
#
# Sie übertragen Wahrheitstabellen in Python und üben anschließend Verzweigungen sowie eine Eingabeschleife mit Gültigkeitsprüfung. Die Tests verwenden Rückgabewerte, damit sie reproduzierbar bleiben.

# %% [markdown]
# ### So arbeiten Sie mit den Doctests
#
# Die Beispiele in den Funktions-Dokumentationen sind ausführbare Tests. Ergänzen Sie nur den markierten Funktionskörper und lassen Sie die Beispiele zunächst unverändert. Führen Sie am Ende des Notebooks die Zelle **Doctests ausführen** aus. `0 failed` bedeutet, dass alle bisher vorgegebenen Fälle funktionieren. Testen Sie zusätzlich eigene Fälle.

# %%
import doctest

# %% [markdown]
# ## 1. De Morgan als Wahrheitstabelle
#
# Schreiben Sie `de_morgan_tabelle()`. Erzeugen Sie mit Schleifen alle vier Kombinationen für `p` und `q`. Jede Zeile soll aus
#
# ```text
# (p, q, not (p and q), (not p) or (not q))
# ```
#
# bestehen. Die Reihenfolge beginnt mit `False, False` und endet mit `True, True`.

# %%
def de_morgan_tabelle():
    """Erzeugt die Wahrheitstabelle für eine De-Morgan-Regel.

    >>> de_morgan_tabelle()
    [(False, False, True, True), (False, True, True, True), (True, False, True, True), (True, True, False, False)]
    """
    pass

# %% [markdown]
# ## 2. Eine zusammengesetzte Bedingung
#
# Eine Person darf teilnehmen, wenn sie angemeldet ist und entweder bezahlt hat oder eine Freigabe besitzt. Zusätzlich darf sie nicht gesperrt sein. Schreiben Sie `darf_teilnehmen` als eine boolesche Bedingung, ohne unnötige Fallunterscheidungen.

# %%
def darf_teilnehmen(angemeldet, bezahlt, freigabe, gesperrt):
    """Prüft eine zusammengesetzte Teilnahmebedingung.

    >>> darf_teilnehmen(True, True, False, False)
    True
    >>> darf_teilnehmen(True, False, True, False)
    True
    >>> darf_teilnehmen(True, True, True, True)
    False
    >>> darf_teilnehmen(False, True, True, False)
    False
    """
    pass

# %% [markdown]
# ## 3. Erste gültige Zahl aus Eingaben
#
# Schreiben Sie `erste_gueltige_zahl(eingaben, minimum, maximum)`. Die Liste `eingaben` enthält Texte, wie sie von `input()` kommen könnten. Gehen Sie mit einer `while`-Schleife von links nach rechts vor:
#
# 1. Ist der Text eine ganze Zahl?
# 2. Liegt die Zahl im geschlossenen Intervall `[minimum, maximum]`?
# 3. Geben Sie die erste gültige Zahl zurück.
#
# Gibt es keine gültige Eingabe, soll `None` zurückgegeben werden. Eine echte Eingabeschleife können Sie danach als Zusatz mit `input()` bauen.

# %%
def erste_gueltige_zahl(eingaben, minimum, maximum):
    """Liefert die erste gültige Zahl aus einer Folge von Eingabetexten.

    >>> erste_gueltige_zahl(["abc", "0", "7"], 1, 10)
    7
    >>> erste_gueltige_zahl(["-1", "11"], 1, 10) is None
    True
    >>> erste_gueltige_zahl(["  4  "], 1, 4)
    4
    """
    pass

# %% [markdown]
# ### Zusatz: interaktiv
#
# Ersetze die Liste `eingaben` durch wiederholte Aufrufe von `input()`. Die Schleife soll erst enden, wenn eine gültige Zahl eingegeben wurde. Teste die reine Funktion weiter mit Doctests.

# %% [markdown]
# ## Weitere Aufgabensammlung
#
# Die folgenden Aufgaben sind als Auswahl gedacht. Bearbeiten Sie zunächst die Basisaufgaben und wählen Sie danach Zusatzaufgaben mit Beispielen aus dem Alltag oder der Datenanalyse.

# %% [markdown]
# ## 4. Exklusives Oder
#
# Schreiben Sie `exklusives_oder(p, q)`. Das Ergebnis ist nur dann `True`, wenn genau eine der beiden Aussagen wahr ist. Verwenden Sie zunächst keine fertige XOR-Funktion.

# %%
def exklusives_oder(p, q):
    """Gibt True zurück, wenn genau eine Aussage wahr ist.

    >>> exklusives_oder(False, False)
    False
    >>> exklusives_oder(False, True)
    True
    >>> exklusives_oder(True, False)
    True
    >>> exklusives_oder(True, True)
    False
    """
    pass

# %% [markdown]
# ## 5. Mehrheitsentscheidung
#
# Schreiben Sie `mehrheitsentscheidung(a, b, c)`. Drei einfache Modelle stimmen über eine Klassifikation ab; geben Sie die boolesche Mehrheit zurück. Dieses Muster erinnert an eine kleine Ensemble-Entscheidung.

# %%
def mehrheitsentscheidung(a, b, c):
    """Gibt die Mehrheitsentscheidung von drei booleschen Stimmen zurück.

    >>> mehrheitsentscheidung(True, True, False)
    True
    >>> mehrheitsentscheidung(False, True, False)
    False
    >>> mehrheitsentscheidung(True, True, True)
    True
    >>> mehrheitsentscheidung(False, False, False)
    False
    """
    pass

# %% [markdown]
# ## 6. Ampelfarbe für einen Messwert
#
# Schreiben Sie `ampel_farbe(wert)`: Unter 50 heißt `"gruen"`, von 50 bis unter 80 `"gelb"`, ab 80 `"rot"`. Solche Schwellwerte werden oft zur Überwachung von Sensoren verwendet.

# %%
def ampel_farbe(wert):
    """Ordnet einen Messwert einer Ampelfarbe zu.

    >>> ampel_farbe(20)
    'gruen'
    >>> ampel_farbe(50)
    'gelb'
    >>> ampel_farbe(79.9)
    'gelb'
    >>> ampel_farbe(80)
    'rot'
    """
    pass

# %% [markdown]
# ## 7. Einzelnen Messwert validieren
#
# Schreiben Sie `messwert_gueltig(wert, minimum, maximum)`. `None` gilt als ungültig; ansonsten muss der Wert im geschlossenen Intervall liegen.

# %%
def messwert_gueltig(wert, minimum, maximum):
    """Prüft einen einzelnen Messwert inklusive fehlender Werte.

    >>> messwert_gueltig(5, 0, 10)
    True
    >>> messwert_gueltig(10, 0, 10)
    True
    >>> messwert_gueltig(11, 0, 10)
    False
    >>> messwert_gueltig(None, 0, 10)
    False
    """
    pass

# %% [markdown]
# ## 8. Gültige Messwerte herausfiltern
#
# Schreiben Sie `filtere_messwerte(werte, minimum, maximum)`. Geben Sie nur gültige Werte in ihrer ursprünglichen Reihenfolge zurück.

# %%
def filtere_messwerte(werte, minimum, maximum):
    """Filtert fehlende oder außerhalb liegende Messwerte heraus.

    >>> filtere_messwerte([1, None, 5, 12, 8], 0, 10)
    [1, 5, 8]
    >>> filtere_messwerte([], 0, 10)
    []
    """
    pass

# %% [markdown]
# ## 9. Datenqualität zählen
#
# Schreiben Sie `datenqualitaet(werte, minimum, maximum)`. Geben Sie `(gueltig, ungueltig)` zurück. Verwenden Sie einen Zähler für beide Gruppen.

# %%
def datenqualitaet(werte, minimum, maximum):
    """Zählt gültige und ungültige Messwerte.

    >>> datenqualitaet([1, None, 5, 12, 8], 0, 10)
    (3, 2)
    >>> datenqualitaet([], 0, 10)
    (0, 0)
    """
    pass

# %% [markdown]
# ## 10. BMI-Kategorie als Verzweigung
#
# Schreiben Sie `bmi_kategorie(gewicht, groesse)`. Berechnen Sie zuerst `gewicht / groesse**2` und geben Sie nach den üblichen groben Schwellen `Untergewicht`, `Normalbereich`, `Übergewicht` oder `Adipositas` zurück. Die Aufgabe dient nur dem Üben von Bedingungen, nicht einer medizinischen Diagnose.

# %%
def bmi_kategorie(gewicht, groesse):
    """Ordnet einen BMI grob einer Kategorie zu.

    >>> bmi_kategorie(60, 1.70)
    'Normalbereich'
    >>> bmi_kategorie(50, 1.70)
    'Untergewicht'
    >>> bmi_kategorie(80, 1.70)
    'Übergewicht'
    >>> bmi_kategorie(110, 1.70)
    'Adipositas'
    """
    pass

# %% [markdown]
# ## 11. Ja-Nein-Eingaben verstehen
#
# Schreiben Sie `parse_ja_nein(text)`. Akzeptieren Sie unabhängig von Groß-/Kleinschreibung `j`, `ja`, `n` und `nein`; bei allen anderen Texten soll `None` zurückkommen.

# %%
def parse_ja_nein(text):
    """Wandelt typische Ja-Nein-Texte in True, False oder None um.

    >>> parse_ja_nein('Ja')
    True
    >>> parse_ja_nein('  N  ')
    False
    >>> parse_ja_nein('vielleicht') is None
    True
    """
    pass

# %% [markdown]
# ## 12. Erste gültige Ja-Nein-Antwort
#
# Schreiben Sie `erste_gueltige_antwort(antworten)`. Durchlaufen Sie die Texte mit einer `while`-Schleife und geben Sie die erste echte boolesche Antwort zurück. Gibt es keine, liefern Sie `None`.

# %%
def erste_gueltige_antwort(antworten):
    """Liefert die erste verständliche Ja-Nein-Antwort.

    >>> erste_gueltige_antwort(['vielleicht', 'J'])
    True
    >>> erste_gueltige_antwort(['?', 'nein', 'ja'])
    False
    >>> erste_gueltige_antwort(['?', 'später']) is None
    True
    """
    pass

# %% [markdown]
# ## 13. Toleranzband prüfen
#
# Schreiben Sie `im_toleranzband(wert, ziel, toleranz)`. Ein Wert liegt im Band, wenn `ziel-toleranz <= wert <= ziel+toleranz` gilt.

# %%
def im_toleranzband(wert, ziel, toleranz):
    """Prüft, ob ein Wert in einem symmetrischen Toleranzband liegt.

    >>> im_toleranzband(9.5, 10, 0.5)
    True
    >>> im_toleranzband(10.6, 10, 0.5)
    False
    >>> im_toleranzband(10, 10, 0)
    True
    """
    pass

# %% [markdown]
# ## Doctests ausführen

# %%
ergebnis = doctest.testmod(globs=globals(), verbose=True)
print(ergebnis)
