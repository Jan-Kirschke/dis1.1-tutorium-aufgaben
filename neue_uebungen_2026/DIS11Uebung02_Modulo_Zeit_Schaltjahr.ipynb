# %% [markdown]
# # 2. Übung: Modulo, Zeitumrechnung und Schaltjahre
#
# In dieser Übung verwenden Sie `//` und `%` für die Zeitumrechnung und formulieren Bedingungen mit `if`, `elif` und `else`. Die Aufgaben entsprechen dem Praktikum zu Zeitumrechnung und Schaltjahrprüfung.
#
# Die Funktionen sollen für die angegebenen sinnvollen Werte arbeiten. Eine interaktive Eingabe ist hier nicht nötig: Durch die Rückgabewerte lassen sich die Funktionen mit Doctests zuverlässig prüfen.

# %% [markdown]
# ### So arbeiten Sie mit den Doctests
#
# Die Beispiele in den Funktions-Dokumentationen sind ausführbare Tests. Ergänzen Sie nur den markierten Funktionskörper und lassen Sie die Beispiele zunächst unverändert. Führen Sie am Ende des Notebooks die Zelle **Doctests ausführen** aus. `0 failed` bedeutet, dass alle bisher vorgegebenen Fälle funktionieren. Testen Sie zusätzlich eigene Fälle.

# %%
import doctest

# %% [markdown]
# ## 1. Schaltjahrprüfung
#
# Schreiben Sie `ist_schaltjahr(jahr)` nach der gregorianischen Regel:
#
# * Durch 4 teilbar genügt meistens.
# * Durch 100 teilbare Jahre sind keine Schaltjahre.
# * Durch 400 teilbare Jahre sind wieder Schaltjahre.

# %%
def ist_schaltjahr(jahr):
    """Prüft, ob ein Jahr ein Schaltjahr ist.

    >>> ist_schaltjahr(2024)
    True
    >>> ist_schaltjahr(2025)
    False
    >>> ist_schaltjahr(1900)
    False
    >>> ist_schaltjahr(2000)
    True
    """
    pass

# %% [markdown]
# ## 2. Sekunden in Uhrzeit zerlegen
#
# Schreiben Sie `sekunden_zu_zeit(sekunden)`. Die Eingabe liegt zwischen `0` und `86399`. Geben Sie ein Tupel `(stunde, minute, sekunde)` zurück. Nutzen Sie ganzzahlige Division und den Restoperator.

# %%
def sekunden_zu_zeit(sekunden):
    """Wandelt Sekunden seit Mitternacht in (Stunde, Minute, Sekunde) um.

    >>> sekunden_zu_zeit(0)
    (0, 0, 0)
    >>> sekunden_zu_zeit(59)
    (0, 0, 59)
    >>> sekunden_zu_zeit(60)
    (0, 1, 0)
    >>> sekunden_zu_zeit(3661)
    (1, 1, 1)
    >>> sekunden_zu_zeit(86399)
    (23, 59, 59)
    """
    pass

# %% [markdown]
# ## 3. Uhrzeit zurück in Sekunden
#
# Schreiben Sie die Umkehrfunktion `zeit_zu_sekunden(stunde, minute, sekunde)`. Verwenden Sie die Formel
#
# ```text
# stunde * 3600 + minute * 60 + sekunde
# ```

# %%
def zeit_zu_sekunden(stunde, minute, sekunde):
    """Wandelt eine Uhrzeit in Sekunden seit Mitternacht um.

    >>> zeit_zu_sekunden(0, 0, 0)
    0
    >>> zeit_zu_sekunden(1, 1, 1)
    3661
    >>> zeit_zu_sekunden(23, 59, 59)
    86399
    """
    pass

# %% [markdown]
# ## 4. Tage eines Monats
#
# Schreiben Sie `tage_im_monat(monat, jahr)`. Berücksichtigen Sie die Monatslängen und den Februar. Verwenden Sie Ihre Funktion `ist_schaltjahr`.

# %%
def tage_im_monat(monat, jahr):
    """Gibt die Anzahl der Tage eines Monats zurück.

    >>> tage_im_monat(1, 2025)
    31
    >>> tage_im_monat(4, 2025)
    30
    >>> tage_im_monat(2, 2024)
    29
    >>> tage_im_monat(2, 2025)
    28
    """
    pass

# %% [markdown]
# ## 5. Ist ein Datum gültig? (Zusatz)
#
# Schreiben Sie `datum_gueltig(tag, monat, jahr)`. Die Funktion liefert `True` oder `False`. Prüfen Sie zuerst den Monat und vergleichen Sie dann den Tag mit `tage_im_monat`.

# %%
def datum_gueltig(tag, monat, jahr):
    """Prüft ein Datum im gregorianischen Kalender.

    >>> datum_gueltig(29, 2, 2024)
    True
    >>> datum_gueltig(29, 2, 2025)
    False
    >>> datum_gueltig(31, 4, 2025)
    False
    >>> datum_gueltig(1, 13, 2025)
    False
    """
    pass

# %% [markdown]
# ## Weitere Aufgabensammlung
#
# Die folgenden Aufgaben sind als Auswahl gedacht. Bearbeiten Sie zunächst die Basisaufgaben und wählen Sie danach Zusatzaufgaben mit Beispielen aus dem Alltag oder der Datenanalyse.

# %% [markdown]
# ## 6. Teilbarkeit prüfen
#
# Schreiben Sie `teilbar(zahl, teiler)`. Die Funktion liefert mit `%` genau dann `True`, wenn kein Rest bleibt. Verwenden Sie positive Teiler.

# %%
def teilbar(zahl, teiler):
    """Prüft, ob zahl ohne Rest durch teiler teilbar ist.

    >>> teilbar(42, 7)
    True
    >>> teilbar(43, 7)
    False
    >>> teilbar(0, 5)
    True
    """
    pass

# %% [markdown]
# ## 7. Daten in Batches aufteilen
#
# Schreiben Sie `batch_aufteilung(anzahl, batchgroesse)`. Geben Sie `(vollstaendige_batches, rest)` zurück. Dieses Muster kommt beim Aufteilen eines Datensatzes in Mini-Batches vor.

# %%
def batch_aufteilung(anzahl, batchgroesse):
    """Zerlegt eine Anzahl von Elementen in volle Batches und Rest.

    >>> batch_aufteilung(103, 20)
    (5, 3)
    >>> batch_aufteilung(100, 20)
    (5, 0)
    >>> batch_aufteilung(7, 10)
    (0, 7)
    """
    pass

# %% [markdown]
# ## 8. Uhrzeit formatiert ausgeben
#
# Schreiben Sie `zeit_als_text(stunde, minute, sekunde)`. Stunden, Minuten und Sekunden sollen jeweils zweistellig erscheinen.

# %%
def zeit_als_text(stunde, minute, sekunde):
    """Formatiert eine Uhrzeit im Format HH:MM:SS.

    >>> zeit_als_text(7, 5, 9)
    '07:05:09'
    >>> zeit_als_text(23, 59, 59)
    '23:59:59'
    """
    pass

# %% [markdown]
# ## 9. Zeitdifferenz am selben Tag
#
# Schreiben Sie `zeitdifferenz(start, ende)`. Beide Argumente sind Tupel `(stunde, minute, sekunde)`, und `ende` liegt nicht vor `start`. Geben Sie die Differenz in Sekunden zurück.

# %%
def zeitdifferenz(start, ende):
    """Berechnet die Differenz zweier Uhrzeiten in Sekunden.

    >>> zeitdifferenz((9, 15, 0), (10, 0, 0))
    2700
    >>> zeitdifferenz((12, 0, 0), (12, 0, 1))
    1
    >>> zeitdifferenz((8, 30, 0), (8, 30, 0))
    0
    """
    pass

# %% [markdown]
# ## 10. Zeitfenster für Sensordaten
#
# Schreiben Sie `zeitfenster_enthaelt(zeit, start, ende)`. Das Zeitfenster ist vorne inklusive und hinten exklusiv: `[start, ende)`. So können benachbarte Zeitfenster ohne Überschneidung verwendet werden.

# %%
def zeitfenster_enthaelt(zeit, start, ende):
    """Prüft, ob zeit im halboffenen Zeitfenster [start, ende) liegt.

    >>> zeitfenster_enthaelt((9, 30, 0), (9, 0, 0), (12, 0, 0))
    True
    >>> zeitfenster_enthaelt((12, 0, 0), (9, 0, 0), (12, 0, 0))
    False
    >>> zeitfenster_enthaelt((8, 59, 59), (9, 0, 0), (12, 0, 0))
    False
    """
    pass

# %% [markdown]
# ## 11. Jahrestag eines Datums
#
# Schreiben Sie `jahrestag(tag, monat, jahr)`. Der 1. Januar hat die Nummer 1. Verwenden Sie eine Schleife über die vorherigen Monate und berücksichtigen Sie Schaltjahre.

# %%
def jahrestag(tag, monat, jahr):
    """Gibt die laufende Tagesnummer eines Datums zurück.

    >>> jahrestag(1, 1, 2025)
    1
    >>> jahrestag(28, 2, 2025)
    59
    >>> jahrestag(29, 2, 2024)
    60
    >>> jahrestag(31, 12, 2024)
    366
    """
    pass

# %% [markdown]
# ## 12. Tage bis zum Jahresende
#
# Schreiben Sie `tage_bis_jahresende(tag, monat, jahr)`. Zählen Sie die Tage nach dem angegebenen Datum; der 31. Dezember liefert also 0.

# %%
def tage_bis_jahresende(tag, monat, jahr):
    """Berechnet die Zahl der Tage nach einem Datum bis zum Jahresende.

    >>> tage_bis_jahresende(31, 12, 2025)
    0
    >>> tage_bis_jahresende(1, 1, 2025)
    364
    >>> tage_bis_jahresende(1, 1, 2024)
    365
    """
    pass

# %% [markdown]
# ## 13. Nächsten Kalendertag bestimmen
#
# Schreiben Sie `naechster_tag(tag, monat, jahr)`. Geben Sie ein Tupel `(tag, monat, jahr)` zurück und behandeln Sie Monats- und Jahreswechsel.

# %%
def naechster_tag(tag, monat, jahr):
    """Gibt den Folgetag eines gültigen Datums zurück.

    >>> naechster_tag(28, 2, 2024)
    (29, 2, 2024)
    >>> naechster_tag(29, 2, 2024)
    (1, 3, 2024)
    >>> naechster_tag(31, 12, 2025)
    (1, 1, 2026)
    """
    pass

# %% [markdown]
# ## 14. Sekunden eines Jahres
#
# Schreiben Sie `sekunden_im_jahr(jahr)`. Berechnen Sie mithilfe der Schaltjahrprüfung, wie viele Sekunden das Jahr hat. Dies ist eine nützliche Größe für Zeitreihen.

# %%
def sekunden_im_jahr(jahr):
    """Berechnet die Sekundenanzahl eines Jahres.

    >>> sekunden_im_jahr(2025)
    31536000
    >>> sekunden_im_jahr(2024)
    31622400
    """
    pass

# %% [markdown]
# ## 15. Datum im ISO-Format
#
# Schreiben Sie `datum_als_iso(tag, monat, jahr)`. Formatieren Sie ein Datum als `JJJJ-MM-TT`, damit es alphabetisch und chronologisch sortierbar ist.

# %%
def datum_als_iso(tag, monat, jahr):
    """Formatiert ein Datum nach ISO 8601.

    >>> datum_als_iso(3, 2, 2026)
    '2026-02-03'
    >>> datum_als_iso(20, 10, 2026)
    '2026-10-20'
    """
    pass

# %% [markdown]
# ## Doctests ausführen

# %%
ergebnis = doctest.testmod(globs=globals(), verbose=True)
print(ergebnis)
